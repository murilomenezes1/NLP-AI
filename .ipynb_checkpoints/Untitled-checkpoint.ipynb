# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### Remoção de dados NaN

# %%
df_reviews = pd.read_csv('./olist_order_reviews_dataset.csv').dropna()
df_reviews.head(5)
# Out:
#                            review_id                          order_id  \
# 9   8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 15  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# 19  373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 22  d21bbc789670eab777d27372ab9094cc  4fc44d78867142c627497b60a7e0228a
# 34  c92cdd7dd544a01aa35137f901669cdf  37e7875cdce5a9e5b3a692971f370151
#
#     review_score     review_comment_title  \
# 9              4                recomendo
# 15             5          Super recomendo
# 19             1  Não chegou meu produto
# 22             5                    Ótimo
# 34             4               Muito bom.
#
#                                review_comment_message review_creation_date  \
# 9   aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 15  Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ...

# %% [markdown]
# ### Recorte de avaliações de 2 estrelas ou menos

# %%
bad_reviews = df_reviews[df_reviews['review_score'] <= 2]
bad_reviews
# Out:
#                               review_id                          order_id  \
# 19     373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 167    5f938e5f5f2e9a75710b54feeb9ea610  d9ff0185a300435402f043124f530274
# 190    c40a6b6e0181e5ec0d12cbc2e12c49d3  f3468d6a2c7586711e9952242898aad4
# 197    06f47dacd0575e592bf6a17e922ce6cd  82348f1b5f24ac795fa9320e02c49553
# 276    f7eb8792e67d53e01a224bfa9b6802b2  a0f2f8b0523207a13f02225bc812ed23
# ...                                 ...                               ...
# 98956  44380245bf1a49875542ea0e7f216986  98efe48952662e6a45a1dc51770039d2
# 99055  5dcc936952f7e67f7faa64c8f57e97a9  719a2a4825d52ce82cbc8698a71495ba
# 99086  7b85c6acaddb354af9aa840528838d9f  33a3edb84b9df4cb49546859b990ac6d
# 99117  61249dd0992d25082ab94464a2a47668  2437dfd68fb453ad27e1898c8b1fe868
# 99200  2ee221b28e5b6fceffac59487ed39348  f2d12dd37eaef72ed7b1186b2edefbcd
#
#        review_score       review_comment_title  \
# ...

# %% [markdown]
# ## Análise 1: Frequência de tokens unicos nos dados de entrada
#
# ### Implementação de stopwords e CountVectorizer

# %%
from nltk.corpus import stopwords

stopwords_portuguese = stopwords.words('portuguese')

# %%
vectorizer = CountVectorizer(max_features=5000, stop_words=stopwords_portuguese, binary=True)
x = vectorizer.fit_transform(bad_reviews['review_comment_message'])
x = np.sum(x, axis=0)

# %% [markdown]
# ### Visualização dos dados

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %% [markdown]
# ## Análise 2: Frequência de bigramas unicos nos dados de entrada
#
# ### Implementação de stopwords e CountVectorizer

# %%
vectorizer = CountVectorizer(max_features=5000, stop_words=stopwords_portuguese, binary=True, ngram_range=(2,2))
x = vectorizer.fit_transform(bad_reviews['review_comment_message'])
x = np.sum(x, axis=0)

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
vectorizer = CountVectorizer(max_features=5000, stop_words=stopwords_portuguese, binary=True, ngram_range=(3,3))
x = vectorizer.fit_transform(bad_reviews['review_comment_message'])
x = np.sum(x, axis=0)

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
vectorizer = CountVectorizer(max_features=5000, stop_words=stopwords_portuguese, binary=True, ngram_range=(4,4))
x = vectorizer.fit_transform(bad_reviews['review_comment_message'])
x = np.sum(x, axis=0)

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
|
